# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import w_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
weather_url = f"{url}appid={w_key}&units={units}&q="

responses = []

print("Beginning Data Retrieval")
print("------------------------------")
record = 1
try:
    for city in cities:
        city_data = requests.get(weather_url + city).json()
        responses.append(city_data) 
        print(f"Processing record {record} of set x | {city}")
        record = record +1
except:
    print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing record 1 of set x | kahului
# Processing record 2 of set x | tasiilaq
# Processing record 3 of set x | namibe
# Processing record 4 of set x | barrow
# Processing record 5 of set x | gornyy
# Processing record 6 of set x | umm lajj
# Processing record 7 of set x | bluff
# Processing record 8 of set x | tiksi
# Processing record 9 of set x | avarua
# Processing record 10 of set x | illoqqortoormiut
# Processing record 11 of set x | cape town
# Processing record 12 of set x | chumikan
# Processing record 13 of set x | rocha
# Processing record 14 of set x | ushuaia
# Processing record 15 of set x | upernavik
# Processing record 16 of set x | les cayes
# Processing record 17 of set x | san jeronimo
# Processing record 18 of set x | jurilovca
# Processing record 19 of set x | kodinsk
# Processing record 20 of set x | ambon
# Processing record 21 of set x | geraldton
# Processing record 22 of set x | guerrero negro
# Processing record 23 of set x | pithiviers
# Processing record 24 of set x | baykit
# Processing record 25 of set x | butaritari
# Processing record 26 of set x | belaya kholunitsa
# Processing record 27 of set x | rikitea
# Processing record 28 of set x | muzquiz
# Processing record 29 of set x | luderitz
# Processing record 30 of set x | rungata
# Processing record 31 of set x | mataura
# Processing record 32 of set x | lebu
# Processing record 33 of set x | louisbourg
# Processing record 34 of set x | lata
# Processing record 35 of set x | cabinda
# Processing record 36 of set x | juli
# Processing record 37 of set x | nyurba
# Processing record 38 of set x | san cristobal
# Processing record 39 of set x | iskateley
# Processing record 40 of set x | taolanaro
# Processing record 41 of set x | vaini
# Processing record 42 of set x | mahon
# Processing record 43 of set x | punta arenas
# Processing record 44 of set x | rafaela
# Processing record 45 of set x | saldanha
# Processing record 46 of set x | busselton
# Processing record 47 of set x | la tuque
# Processing record 48 of set x | yellowknife
# Processing record 49 of set x | jamestown
# Processing record 50 of set x | mys shmidta
# Processing record 51 of set x | hobart
# Processing record 52 of set x | kajaani
# Processing record 53 of set x | faanui
# Processing record 54 of set x | severo-kurilsk
# Processing record 55 of set x | carutapera
# Processing record 56 of set x | atuona
# Processing record 57 of set x | kasama
# Processing record 58 of set x | shizunai
# Processing record 59 of set x | marsh harbour
# Processing record 60 of set x | leningradskiy
# Processing record 61 of set x | turtkul
# Processing record 62 of set x | bredasdorp
# Processing record 63 of set x | tuktoyaktuk
# Processing record 64 of set x | east london
# Processing record 65 of set x | castro
# Processing record 66 of set x | palimbang
# Processing record 67 of set x | marsa matruh
# Processing record 68 of set x | vila franca do campo
# Processing record 69 of set x | beringovskiy
# Processing record 70 of set x | amderma
# Processing record 71 of set x | russell
# Processing record 72 of set x | zomba
# Processing record 73 of set x | minnedosa
# Processing record 74 of set x | banjar
# Processing record 75 of set x | kodiak
# Processing record 76 of set x | rio verde de mato grosso
# Processing record 77 of set x | nikolskoye
# Processing record 78 of set x | oum hadjer
# Processing record 79 of set x | cherskiy
# Processing record 80 of set x | atar
# Processing record 81 of set x | tsihombe
# Processing record 82 of set x | burnie
# Processing record 83 of set x | karamea
# Processing record 84 of set x | mitu
# Processing record 85 of set x | port alfred
# Processing record 86 of set x | vila velha
# Processing record 87 of set x | forest lake
# Processing record 88 of set x | peachland
# Processing record 89 of set x | fort nelson
# Processing record 90 of set x | huangnihe
# Processing record 91 of set x | gogrial
# Processing record 92 of set x | garowe
# Processing record 93 of set x | ugoofaaru
# Processing record 94 of set x | taoudenni
# Processing record 95 of set x | qaanaaq
# Processing record 96 of set x | flinders
# Processing record 97 of set x | luau
# Processing record 98 of set x | bayir
# Processing record 99 of set x | gobabis
# Processing record 100 of set x | klaksvik
# Processing record 101 of set x | naze
# Processing record 102 of set x | dymer
# Processing record 103 of set x | bhag
# Processing record 104 of set x | teya
# Processing record 105 of set x | albany
# Processing record 106 of set x | port elizabeth
# Processing record 107 of set x | manokwari
# Processing record 108 of set x | chapais
# Processing record 109 of set x | pacific grove
# Processing record 110 of set x | komsomolskiy
# Processing record 111 of set x | hilo
# Processing record 112 of set x | labutta
# Processing record 113 of set x | nome
# Processing record 114 of set x | arraial do cabo
# Processing record 115 of set x | quatre cocos
# Processing record 116 of set x | latung
# Processing record 117 of set x | touros
# Processing record 118 of set x | barentsburg
# Processing record 119 of set x | rock springs
# Processing record 120 of set x | qaqortoq
# Processing record 121 of set x | zavyalovo
# Processing record 122 of set x | katobu
# Processing record 123 of set x | mahajanga
# Processing record 124 of set x | vostok
# Processing record 125 of set x | constitucion
# Processing record 126 of set x | port hedland
# Processing record 127 of set x | visnes
# Processing record 128 of set x | lorengau
# Processing record 129 of set x | beaufort
# Processing record 130 of set x | roald
# Processing record 131 of set x | marcona
# Processing record 132 of set x | husavik
# Processing record 133 of set x | lavrentiya
# Processing record 134 of set x | diffa
# Processing record 135 of set x | tsumeb
# Processing record 136 of set x | tuatapere
# Processing record 137 of set x | shigony
# Processing record 138 of set x | shingu
# Processing record 139 of set x | fortuna
# Processing record 140 of set x | jiwani
# Processing record 141 of set x | coquimbo
# Processing record 142 of set x | grand river south east
# Processing record 143 of set x | ajdabiya
# Processing record 144 of set x | airai
# Processing record 145 of set x | vaitupu
# Processing record 146 of set x | puerto ayora
# Processing record 147 of set x | griffith
# Processing record 148 of set x | ambovombe
# Processing record 149 of set x | lompoc
# Processing record 150 of set x | port blair
# Processing record 151 of set x | raga
# Processing record 152 of set x | hermanus
# Processing record 153 of set x | necochea
# Processing record 154 of set x | campeche
# Processing record 155 of set x | mahebourg
# Processing record 156 of set x | bangarmau
# Processing record 157 of set x | cidreira
# Processing record 158 of set x | ust-maya
# Processing record 159 of set x | ilulissat
# Processing record 160 of set x | hobyo
# Processing record 161 of set x | hakkari
# Processing record 162 of set x | saint anthony
# Processing record 163 of set x | ancud
# Processing record 164 of set x | arona
# Processing record 165 of set x | jijiga
# Processing record 166 of set x | ouro preto do oeste
# Processing record 167 of set x | rong kwang
# Processing record 168 of set x | evensk
# Processing record 169 of set x | muros
# Processing record 170 of set x | kaitangata
# Processing record 171 of set x | chokurdakh
# Processing record 172 of set x | saleaula
# Processing record 173 of set x | belaya gora
# Processing record 174 of set x | college
# Processing record 175 of set x | mizan teferi
# Processing record 176 of set x | bengkulu
# Processing record 177 of set x | vanimo
# Processing record 178 of set x | kapaa
# Processing record 179 of set x | kutahya
# Processing record 180 of set x | ponta do sol
# Processing record 181 of set x | jutai
# Processing record 182 of set x | avera
# Processing record 183 of set x | banes
# Processing record 184 of set x | yatou
# Processing record 185 of set x | matagami
# Processing record 186 of set x | manzanillo
# Processing record 187 of set x | concordia
# Processing record 188 of set x | athabasca
# Processing record 189 of set x | vila do maio
# Processing record 190 of set x | kysyl-syr
# Processing record 191 of set x | kawana waters
# Processing record 192 of set x | mar del plata
# Processing record 193 of set x | saint george
# Processing record 194 of set x | taksimo
# Processing record 195 of set x | san miguel
# Processing record 196 of set x | asau
# Processing record 197 of set x | kununurra
# Processing record 198 of set x | palmer
# Processing record 199 of set x | azangaro
# Processing record 200 of set x | samusu
# Processing record 201 of set x | acapulco
# Processing record 202 of set x | malakal
# Processing record 203 of set x | sabha
# Processing record 204 of set x | hithadhoo
# Processing record 205 of set x | iqaluit
# Processing record 206 of set x | bethel
# Processing record 207 of set x | victoria
# Processing record 208 of set x | nhulunbuy
# Processing record 209 of set x | pisco
# Processing record 210 of set x | khatanga
# Processing record 211 of set x | mascote
# Processing record 212 of set x | pangnirtung
# Processing record 213 of set x | emba
# Processing record 214 of set x | ferkessedougou
# Processing record 215 of set x | aksu
# Processing record 216 of set x | pizarro
# Processing record 217 of set x | tubigan
# Processing record 218 of set x | utete
# Processing record 219 of set x | sungaipenuh
# Processing record 220 of set x | tanete
# Processing record 221 of set x | attawapiskat
# Processing record 222 of set x | port hardy
# Processing record 223 of set x | abu samrah
# Processing record 224 of set x | yanam
# Processing record 225 of set x | meulaboh
# Processing record 226 of set x | palabuhanratu
# Processing record 227 of set x | lasa
# Processing record 228 of set x | carman
# Processing record 229 of set x | monze
# Processing record 230 of set x | umzimvubu
# Processing record 231 of set x | nautla
# Processing record 232 of set x | santa rita
# Processing record 233 of set x | labuhan
# Processing record 234 of set x | new norfolk
# Processing record 235 of set x | ketchikan
# Processing record 236 of set x | moindou
# Processing record 237 of set x | axim
# Processing record 238 of set x | meyungs
# Processing record 239 of set x | broome
# Processing record 240 of set x | zhob
# Processing record 241 of set x | mahibadhoo
# Processing record 242 of set x | codrington
# Processing record 243 of set x | shimoda
# Processing record 244 of set x | khorramshahr
# Processing record 245 of set x | maragogi
# Processing record 246 of set x | kamenka
# Processing record 247 of set x | jan kempdorp
# Processing record 248 of set x | dangriga
# Processing record 249 of set x | nchelenge
# Processing record 250 of set x | pevek
# Processing record 251 of set x | lokosovo
# Processing record 252 of set x | marawi
# Processing record 253 of set x | port lincoln
# Processing record 254 of set x | irituia
# Processing record 255 of set x | alcantara
# Processing record 256 of set x | bronnoysund
# Processing record 257 of set x | kavieng
# Processing record 258 of set x | yerbogachen
# Processing record 259 of set x | krasnyye baki
# Processing record 260 of set x | porterville
# Processing record 261 of set x | rincon
# Processing record 262 of set x | golden
# Processing record 263 of set x | tarudant
# Processing record 264 of set x | merauke
# Processing record 265 of set x | pontypool
# Processing record 266 of set x | tilichiki
# Processing record 267 of set x | montevideo
# Processing record 268 of set x | de-kastri
# Processing record 269 of set x | nizhnevartovsk
# Processing record 270 of set x | coruripe
# Processing record 271 of set x | ixtapa
# Processing record 272 of set x | presidente medici
# Processing record 273 of set x | maningrida
# Processing record 274 of set x | nanortalik
# Processing record 275 of set x | bathsheba
# Processing record 276 of set x | khryashchevka
# Processing record 277 of set x | peskovka
# Processing record 278 of set x | san juan
# Processing record 279 of set x | kyra
# Processing record 280 of set x | katsuura
# Processing record 281 of set x | souillac
# Processing record 282 of set x | manta
# Processing record 283 of set x | boatlaname
# Processing record 284 of set x | kourou
# Processing record 285 of set x | gatesville
# Processing record 286 of set x | berlevag
# Processing record 287 of set x | vangaindrano
# Processing record 288 of set x | cap malheureux
# Processing record 289 of set x | north smithfield
# Processing record 290 of set x | norman wells
# Processing record 291 of set x | haibowan
# Processing record 292 of set x | sorland
# Processing record 293 of set x | tigil
# Processing record 294 of set x | umm kaddadah
# Processing record 295 of set x | miguel hidalgo
# Processing record 296 of set x | pueblo bello
# Processing record 297 of set x | saint-francois
# Processing record 298 of set x | nizhneyansk
# Processing record 299 of set x | erzin
# Processing record 300 of set x | san jose
# Processing record 301 of set x | morondava
# Processing record 302 of set x | soure
# Processing record 303 of set x | trebisacce
# Processing record 304 of set x | okhotsk
# Processing record 305 of set x | coahuayana
# Processing record 306 of set x | divo
# Processing record 307 of set x | vaxjo
# Processing record 308 of set x | enshi
# Processing record 309 of set x | mnogovershinnyy
# Processing record 310 of set x | saskylakh
# Processing record 311 of set x | hasaki
# Processing record 312 of set x | mathathane
# Processing record 313 of set x | neuquen
# Processing record 314 of set x | ribeira grande
# Processing record 315 of set x | govindgarh
# Processing record 316 of set x | smithers
# Processing record 317 of set x | berdigestyakh
# Processing record 318 of set x | sembe
# Processing record 319 of set x | fairbanks
# Processing record 320 of set x | cockburn town
# Processing record 321 of set x | bonavista
# Processing record 322 of set x | mindelo
# Processing record 323 of set x | mareeba
# Processing record 324 of set x | iralaya
# Processing record 325 of set x | launceston
# Processing record 326 of set x | yazman
# Processing record 327 of set x | hamilton
# Processing record 328 of set x | cap-aux-meules
# Processing record 329 of set x | olafsvik
# Processing record 330 of set x | goderich
# Processing record 331 of set x | bakel
# Processing record 332 of set x | poum
# Processing record 333 of set x | esmeraldas
# Processing record 334 of set x | ulcinj
# Processing record 335 of set x | monrovia
# Processing record 336 of set x | tianpeng
# Processing record 337 of set x | saint-philippe
# Processing record 338 of set x | leh
# Processing record 339 of set x | yelandur
# Processing record 340 of set x | teluk nibung
# Processing record 341 of set x | burica
# Processing record 342 of set x | hendek
# Processing record 343 of set x | dovers
# Processing record 344 of set x | paita
# Processing record 345 of set x | portsmouth
# Processing record 346 of set x | maceio
# Processing record 347 of set x | thinadhoo
# Processing record 348 of set x | san andres
# Processing record 349 of set x | marzuq
# Processing record 350 of set x | gejiu
# Processing record 351 of set x | ginir
# Processing record 352 of set x | ardmore
# Processing record 353 of set x | skovorodino
# Processing record 354 of set x | birin
# Processing record 355 of set x | sitka
# Processing record 356 of set x | ust-nera
# Processing record 357 of set x | scottsburgh
# Processing record 358 of set x | cabo san lucas
# Processing record 359 of set x | nagua
# Processing record 360 of set x | graaff-reinet
# Processing record 361 of set x | pinawa
# Processing record 362 of set x | nouadhibou
# Processing record 363 of set x | hambantota
# Processing record 364 of set x | port macquarie
# Processing record 365 of set x | provideniya
# Processing record 366 of set x | santa fe
# Processing record 367 of set x | almaznyy
# Processing record 368 of set x | san patricio
# Processing record 369 of set x | narsaq
# Processing record 370 of set x | mogadishu
# Processing record 371 of set x | talaigua
# Processing record 372 of set x | coracao de maria
# Processing record 373 of set x | lagoa
# Processing record 374 of set x | aklavik
# Processing record 375 of set x | saint-georges
# Processing record 376 of set x | gat
# Processing record 377 of set x | gamba
# Processing record 378 of set x | christchurch
# Processing record 379 of set x | severnyy
# Processing record 380 of set x | dunedin
# Processing record 381 of set x | athens
# Processing record 382 of set x | san quintin
# Processing record 383 of set x | havre-saint-pierre
# Processing record 384 of set x | belushya guba
# Processing record 385 of set x | tezu
# Processing record 386 of set x | georgetown
# Processing record 387 of set x | vardo
# Processing record 388 of set x | dikson
# Processing record 389 of set x | hammerfest
# Processing record 390 of set x | sentyabrskiy
# Processing record 391 of set x | mana
# Processing record 392 of set x | namatanai
# Processing record 393 of set x | hay river
# Processing record 394 of set x | maridi
# Processing record 395 of set x | colares
# Processing record 396 of set x | baiyin
# Processing record 397 of set x | mopti
# Processing record 398 of set x | yabelo
# Processing record 399 of set x | filingue
# Processing record 400 of set x | ahuimanu
# Processing record 401 of set x | paamiut
# Processing record 402 of set x | kpalime
# Processing record 403 of set x | panaba
# Processing record 404 of set x | shitanjing
# Processing record 405 of set x | manono
# Processing record 406 of set x | kati
# Processing record 407 of set x | acajutla
# Processing record 408 of set x | sao filipe
# Processing record 409 of set x | teguldet
# Processing record 410 of set x | bucak
# Processing record 411 of set x | esperance
# Processing record 412 of set x | la asuncion
# Processing record 413 of set x | anloga
# Processing record 414 of set x | nortelandia
# Processing record 415 of set x | inhambane
# Processing record 416 of set x | hualmay
# Processing record 417 of set x | gornopravdinsk
# Processing record 418 of set x | juneau
# Processing record 419 of set x | sheridan
# Processing record 420 of set x | ilebo
# Processing record 421 of set x | beipiao
# Processing record 422 of set x | mount darwin
# Processing record 423 of set x | myanaung
# Processing record 424 of set x | salalah
# Processing record 425 of set x | bilma
# Processing record 426 of set x | rudnaya pristan
# Processing record 427 of set x | sao joao da barra
# Processing record 428 of set x | junin
# Processing record 429 of set x | tsogni
# Processing record 430 of set x | north platte
# Processing record 431 of set x | hendijan
# Processing record 432 of set x | isangel
# Processing record 433 of set x | taquarituba
# Processing record 434 of set x | severobaykalsk
# Processing record 435 of set x | valparaiso
# Processing record 436 of set x | jambi
# Processing record 437 of set x | bambous virieux
# Processing record 438 of set x | lac
# Processing record 439 of set x | mayumba
# Processing record 440 of set x | yeppoon
# Processing record 441 of set x | marovoay
# Processing record 442 of set x | hua hin
# Processing record 443 of set x | juegang
# Processing record 444 of set x | mehamn
# Processing record 445 of set x | portland
# Processing record 446 of set x | karratha
# Processing record 447 of set x | havelock
# Processing record 448 of set x | santa cruz
# Processing record 449 of set x | nabire
# Processing record 450 of set x | ishnya
# Processing record 451 of set x | hanko
# Processing record 452 of set x | ust-tsilma
# Processing record 453 of set x | bronnitsy
# Processing record 454 of set x | moron
# Processing record 455 of set x | pocerski pricinovic
# Processing record 456 of set x | coihaique
# Processing record 457 of set x | thompson
# Processing record 458 of set x | ndioum
# Processing record 459 of set x | sistranda
# Processing record 460 of set x | halalo
# Processing record 461 of set x | ramtek
# Processing record 462 of set x | la ronge
# Processing record 463 of set x | sobolevo
# Processing record 464 of set x | high level
# Processing record 465 of set x | davila
# Processing record 466 of set x | kuche
# Processing record 467 of set x | abu kamal
# Processing record 468 of set x | chebsara
# Processing record 469 of set x | ola
# Processing record 470 of set x | karlstad
# Processing record 471 of set x | banda aceh
# Processing record 472 of set x | atambua
# Processing record 473 of set x | xiongzhou
# Processing record 474 of set x | ileza
# Processing record 475 of set x | grindavik
# Processing record 476 of set x | lima
# Processing record 477 of set x | salinopolis
# Processing record 478 of set x | kuching
# Processing record 479 of set x | sur
# Processing record 480 of set x | lishui
# Processing record 481 of set x | usinsk
# Processing record 482 of set x | catio
# Processing record 483 of set x | ibra
# Processing record 484 of set x | oksfjord
# Processing record 485 of set x | harper
# Processing record 486 of set x | chuy
# Processing record 487 of set x | alenquer
# Processing record 488 of set x | dicabisagan
# Processing record 489 of set x | alice town
# Processing record 490 of set x | caceres
# Processing record 491 of set x | mackay
# Processing record 492 of set x | laguna
# Processing record 493 of set x | presidencia roque saenz pena
# Processing record 494 of set x | marataizes
# Processing record 495 of set x | lucatan
# Processing record 496 of set x | broken hill
# Processing record 497 of set x | egvekinot
# Processing record 498 of set x | santa barbara
# Processing record 499 of set x | porto novo
# Processing record 500 of set x | ossora
# Processing record 501 of set x | valdivia
# Processing record 502 of set x | anaconda
# Processing record 503 of set x | baruun-urt
# Processing record 504 of set x | baracoa
# Processing record 505 of set x | karasjok
# Processing record 506 of set x | carnaiba
# Processing record 507 of set x | gwadar
# Processing record 508 of set x | killybegs
# Processing record 509 of set x | wajid
# Processing record 510 of set x | royan
# Processing record 511 of set x | kovdor
# Processing record 512 of set x | loanda
# Processing record 513 of set x | fredericton
# Processing record 514 of set x | bur gabo
# Processing record 515 of set x | oulu
# Processing record 516 of set x | yarmouth
# Processing record 517 of set x | altamira
# Processing record 518 of set x | carnarvon
# Processing record 519 of set x | palembang
# Processing record 520 of set x | rawson
# Processing record 521 of set x | abra de ilog
# Processing record 522 of set x | andra
# Processing record 523 of set x | harlingen
# Processing record 524 of set x | saquarema
# Processing record 525 of set x | rabo de peixe
# Processing record 526 of set x | bull savanna
# Processing record 527 of set x | davydivka
# Processing record 528 of set x | bucerias
# Processing record 529 of set x | korla
# Processing record 530 of set x | jiazi
# Processing record 531 of set x | mount isa
# Processing record 532 of set x | torbay
# Processing record 533 of set x | mayo
# Processing record 534 of set x | derzhavinsk
# Processing record 535 of set x | zeya
# Processing record 536 of set x | tempio pausania
# Processing record 537 of set x | kutum
# Processing record 538 of set x | ust-kuyga
# Processing record 539 of set x | san policarpo
# Processing record 540 of set x | dawei
# Processing record 541 of set x | kruisfontein
# Processing record 542 of set x | krasnoselkup
# Processing record 543 of set x | zhanakorgan
# Processing record 544 of set x | surt
# Processing record 545 of set x | katima mulilo
# Processing record 546 of set x | sumbawa
# Processing record 547 of set x | cayenne
# Processing record 548 of set x | deputatskiy
# Processing record 549 of set x | nouakchott
# Processing record 550 of set x | quang ngai
# Processing record 551 of set x | anqing
# Processing record 552 of set x | gargalianoi
# Processing record 553 of set x | tumannyy
# Processing record 554 of set x | belyy yar
# Processing record 555 of set x | barbar
# Processing record 556 of set x | caravelas
# Processing record 557 of set x | alice springs
# Processing record 558 of set x | gerash
# Processing record 559 of set x | tomatlan
# Processing record 560 of set x | conde
# Processing record 561 of set x | labuan
# Processing record 562 of set x | brigantine
# Processing record 563 of set x | nguiu
# Processing record 564 of set x | chenzhou
# Processing record 565 of set x | atraulia
# Processing record 566 of set x | haapiti
# Processing record 567 of set x | yumaguzino
# Processing record 568 of set x | laela
# Processing record 569 of set x | tessalit
# Processing record 570 of set x | muli
# Processing record 571 of set x | deniliquin
# Processing record 572 of set x | kurchum
# Processing record 573 of set x | starokorsunskaya
# Processing record 574 of set x | hombourg-haut
# Processing record 575 of set x | lamu
# Processing record 576 of set x | vestmannaeyjar
# Processing record 577 of set x | faya
# Processing record 578 of set x | shubarkuduk
# Processing record 579 of set x | phan thiet
# Processing record 580 of set x | stephenville
# Processing record 581 of set x | totolapa
# Processing record 582 of set x | clyde river
# Processing record 583 of set x | hinesville
# Processing record 584 of set x | seymchan
# Processing record 585 of set x | northam
# Processing record 586 of set x | nizwa
# Processing record 587 of set x | mariinsk
# Processing record 588 of set x | ternate
# Processing record 589 of set x | longyearbyen
# Processing record 590 of set x | north bend
# Processing record 591 of set x | olavarria
# Processing record 592 of set x | harbour breton
# Processing record 593 of set x | mount gambier
# Processing record 594 of set x | cascais
# Processing record 595 of set x | tasbuget
# Processing record 596 of set x | alofi
# Processing record 597 of set x | karpogory
# Processing record 598 of set x | margate
# Processing record 599 of set x | jinchang
# Processing record 600 of set x | khonuu
# Processing record 601 of set x | rantepao
# Processing record 602 of set x | okha
# Processing record 603 of set x | obo
# Processing record 604 of set x | mega
# Processing record 605 of set x | chagda
# Processing record 606 of set x | henties bay
# Processing record 607 of set x | cururupu
# Processing record 608 of set x | acarau
# Processing record 609 of set x | weligama
# Processing record 610 of set x | zhanaozen
# Processing record 611 of set x | altay
# Processing record 612 of set x | taloqan
# Processing record 613 of set x | pangai
# Processing record 614 of set x | sinnamary
# Processing record 615 of set x | thohoyandou
# Processing record 616 of set x | bolshiye uki
# Processing record 617 of set x | soe
# Processing record 618 of set x | dezhou
# Processing record 619 of set x | nemuro
# Processing record 620 of set x | znamenskoye
# Processing record 621 of set x | stykkisholmur
# Processing record 622 of set x | zhigansk
# Processing record 623 of set x | port keats
# Processing record 624 of set x | ruatoria
# Processing record 625 of set x | poopo
# Processing record 626 of set x | ngerengere
# Processing record 627 of set x | kosa
# Processing record 628 of set x | zyryanka
# Processing record 629 of set x | cockburn harbour
# Processing record 630 of set x | buraydah
# Processing record 631 of set x | bonfim
# Processing record 632 of set x | solnechnyy
# Processing record 633 of set x | vizinga
# Processing record 634 of set x | khilchipur
# Processing record 635 of set x | wadi maliz
# Processing record 636 of set x | maarianhamina
# Processing record 637 of set x | tautira
# Processing record 638 of set x | springdale
# Processing record 639 of set x | shenkursk
# Processing record 640 of set x | kijang
# Processing record 641 of set x | moba
# Processing record 642 of set x | richards bay

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
responses
# Out:
# [{'coord': {'lon': -156.47, 'lat': 20.89},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 23.76,
#    'feels_like': 24.61,
#    'temp_min': 21.67,
#    'temp_max': 26,
#    'pressure': 1016,
#    'humidity': 61},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 280},
#   'clouds': {'all': 40},
#   'dt': 1579750140,
#   'sys': {'type': 1,
#    'id': 7879,
#    'country': 'US',
#    'sunrise': 1579712690,
#    'sunset': 1579752577},
#   'timezone': -36000,
#   'id': 5847411,
#   'name': 'Kahului',
#   'cod': 200},
#  {'coord': {'lon': -37.64, 'lat': 65.61},
#   'weather': [{'id': 602,
#     'main': 'Snow',
#     'description': 'heavy snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': -8,
#    'feels_like': -22.46,
#    'temp_min': -8,
#    'temp_max': -8,
#    'pressure': 990,
#    'humidity': 61},
#   'wind': {'speed': 15.9, 'deg': 330, 'gust': 23.1},
#   'clouds': {'all': 0},
#   'dt': 1579750331,
#   'sys': {'type': 1,
#    'id': 81,
#    'country': 'GL',
#    'sunrise': 1579780498,
#    'sunset': 1579800554},
#   'timezone': -10800,
#   'id': 3424607,
#   'name': 'Tasiilaq',
#   'cod': 200},
#  {'coord': {'lon': 12.15, 'lat': -15.2},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 23.45,
#    'feels_like': 23.52,
#    'temp_min': 23.45,
#    'temp_max': 23.45,
#    'pressure': 1009,
#    'humidity': 75,
#    'sea_level': 1009,
#    'grnd_level': 1009},
#   'wind': {'speed': 4.37, 'deg': 199},
#   'clouds': {'all': 100},
#   'dt': 1579750193,
#   'sys': {'country': 'AO', 'sunrise': 1579755423, 'sunset': 1579801725},
#   'timezone': 3600,
#   'id': 3347019,
#   'name': 'Mossamedes',
#   'cod': 200},
#  {'coord': {'lon': -156.79, 'lat': 71.29},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': -22,
#    'feels_like': -28.23,
#    'temp_min': -22,
#    'temp_max': -22,
#    'pressure': 1007,
#    'humidity': 83},
#   'visibility': 11265,
#   'wind': {'speed': 3.6, 'deg': 260},
#   'clouds': {'all': 1},
#   'dt': 1579750202,
#   'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 0, 'sunset': 0},
#   'timezone': -32400,
#   'id': 5880054,
#   'name': 'Barrow',
#   'cod': 200},
#  {'coord': {'lon': 83.91, 'lat': 55.12},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': -9.45,
#    'feels_like': -17.47,
#    'temp_min': -9.45,
#    'temp_max': -9.45,
#    'pressure': 1018,
#    'humidity': 91,
#    'sea_level': 1018,
#    'grnd_level': 986},
#   'wind': {'speed': 7.03, 'deg': 193},
#   'clouds': {'all': 95},
#   'dt': 1579750436,
#   'sys': {'country': 'RU', 'sunrise': 1579746704, 'sunset': 1579775993},
#   'timezone': 25200,
#   'id': 1506254,
#   'name': 'Gornyy',
#   'cod': 200},
#  {'coord': {'lon': 37.27, 'lat': 25.02},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 11.2,
#    'feels_like': 4.83,
#    'temp_min': 11.2,
#    'temp_max': 11.2,
#    'pressure': 1020,
#    'humidity': 33,
#    'sea_level': 1020,
#    'grnd_level': 981},
#   'wind': {'speed': 5.45, 'deg': 74},
#   'clouds': {'all': 0},
#   'dt': 1579750436,
#   'sys': {'country': 'SA', 'sunrise': 1579753002, 'sunset': 1579792085},
#   'timezone': 10800,
#   'id': 100926,
#   'name': 'Umm Lajj',
#   'cod': 200},
#  {'coord': {'lon': 168.33, 'lat': -46.6},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 17.78,
#    'feels_like': 14.61,
#    'temp_min': 17.78,
#    'temp_max': 17.78,
#    'pressure': 1016,
#    'humidity': 73},
#   'wind': {'speed': 5.81, 'deg': 218, 'gust': 9.39},
#   'clouds': {'all': 56},
#   'dt': 1579750322,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1579713817,
#    'sunset': 1579768350},
#   'timezone': 46800,
#   'id': 2206939,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 128.87, 'lat': 71.69},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'model',
#   'main': {'temp': -33.4,
#    'feels_like': -38.57,
#    'temp_min': -33.4,
#    'temp_max': -33.4,
#    'pressure': 1022,
#    'humidity': 86,
#    'sea_level': 1022,
#    'grnd_level': 1004},
#   'wind': {'speed': 1.82, 'deg': 244},
#   'clouds': {'all': 48},
#   'dt': 1579750336,
#   'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#   'timezone': 32400,
#   'id': 2015306,
#   'name': 'Tiksi',
#   'cod': 200},
#  {'coord': {'lon': -159.78, 'lat': -21.21},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 27,
#    'feels_like': 30.8,
#    'temp_min': 27,
#    'temp_max': 27,
#    'pressure': 1010,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 340},
#   'rain': {'3h': 2.19},
#   'clouds': {'all': 100},
#   'dt': 1579750323,
#   'sys': {'type': 1,
#    'id': 7271,
#    'country': 'CK',
#    'sunrise': 1579709682,
#    'sunset': 1579757174},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 18.42, 'lat': -33.93},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 18.19,
#    'feels_like': 16,
#    'temp_min': 16.67,
#    'temp_max': 19.44,
#    'pressure': 1011,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 150},
#   'clouds': {'all': 0},
#   'dt': 1579750198,
#   'sys': {'type': 1,
#    'id': 1899,
#    'country': 'ZA',
#    'sunrise': 1579751883,
#    'sunset': 1579802254},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': 135.31, 'lat': 54.72},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'model',
#   'main': {'temp': -18.85,
#    'feels_like': -23.5,
#    'temp_min': -18.85,
#    'temp_max': -18.85,
#    'pressure': 1019,
#    'humidity': 78,
#    'sea_level': 1019,
#    'grnd_level': 990},
#   'wind': {'speed': 1.43, 'deg': 268},
#   'clouds': {'all': 16},
#   'dt': 1579750375,
#   'sys': {'country': 'RU', 'sunrise': 1579734266, 'sunset': 1579763754},
#   'timezone': 36000,
#   'id': 2025256,
#   'name': 'Chumikan',
#   'cod': 200},
#  {'coord': {'lon': -54.33, 'lat': -34.48},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 17.55,
#    'feels_like': 17.99,
#    'temp_min': 17.55,
#    'temp_max': 17.55,
#    'pressure': 1017,
#    'humidity': 96,
#    'sea_level': 1017,
#    'grnd_level': 1004},
#   'wind': {'speed': 2.72, 'deg': 46},
#   'clouds': {'all': 0},
#   'dt': 1579750386,
#   'sys': {'country': 'UY', 'sunrise': 1579769283, 'sunset': 1579819781},
#   'timezone': -10800,
#   'id': 3440777,
#   'name': 'Rocha',
#   'cod': 200},
#  {'coord': {'lon': -68.3, 'lat': -54.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 9,
#    'feels_like': 5.89,
#    'temp_min': 9,
#    'temp_max': 9,
#    'pressure': 1004,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 50},
#   'clouds': {'all': 75},
#   'dt': 1579750321,
#   'sys': {'type': 1,
#    'id': 8303,
#    'country': 'AR',
#    'sunrise': 1579768615,
#    'sunset': 1579827156},
#   'timezone': -10800,
#   'id': 3833367,
#   'name': 'Ushuaia',
#   'cod': 200},
#  {'coord': {'lon': -56.15, 'lat': 72.79},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': -17.6,
#    'feels_like': -23.88,
#    'temp_min': -17.6,
#    'temp_max': -17.6,
#    'pressure': 1004,
#    'humidity': 93,
#    'sea_level': 1004,
#    'grnd_level': 1003},
#   'wind': {'speed': 3.93, 'deg': 160},
#   'snow': {'3h': 0.13},
#   'clouds': {'all': 100},
#   'dt': 1579750339,
#   'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#   'timezone': -10800,
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -73.75, 'lat': 18.2},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'model',
#   'main': {'temp': 26.3,
#    'feels_like': 28.56,
#    'temp_min': 26.3,
#    'temp_max': 26.3,
#    'pressure': 1014,
#    'humidity': 69,
#    'sea_level': 1014,
#    'grnd_level': 1013},
#   'wind': {'speed': 2.15, 'deg': 244},
#   'clouds': {'all': 41},
#   'dt': 1579750438,
#   'sys': {'country': 'HT', 'sunrise': 1579692580, 'sunset': 1579732974},
#   'timezone': -18000,
#   'id': 3728097,
#   'name': 'Les Cayes',
#   'cod': 200},
#  {'coord': {'lon': -75.28, 'lat': -11.95},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 5.85,
#    'feels_like': 3.59,
#    'temp_min': 5.85,
#    'temp_max': 5.85,
#    'pressure': 1019,
#    'humidity': 94,
#    'sea_level': 1019,
#    'grnd_level': 637},
#   'wind': {'speed': 1.61, 'deg': 337},
#   'rain': {'3h': 2.13},
#   'clouds': {'all': 100},
#   'dt': 1579750438,
#   'sys': {'country': 'PE', 'sunrise': 1579690281, 'sunset': 1579736008},
#   'timezone': -18000,
#   'id': 3929611,
#   'name': 'San Jeronimo',
#   'cod': 200},
#  {'coord': {'lon': 28.87, 'lat': 44.77},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 2.08,
#    'feels_like': -4.65,
#    'temp_min': 2,
#    'temp_max': 2.22,
#    'pressure': 1021,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 310},
#   'clouds': {'all': 39},
#   'dt': 1579750438,
#   'sys': {'type': 1,
#    'id': 6924,
#    'country': 'RO',
#    'sunrise': 1579757604,
#    'sunset': 1579791517},
#   'timezone': 7200,
#   'id': 675130,
#   'name': 'Jurilovca',
#   'cod': 200},
#  {'coord': {'lon': 99.18, 'lat': 58.69},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': -25.67,
#    'feels_like': -30.71,
#    'temp_min': -25.67,
#    'temp_max': -25.67,
#    'pressure': 1028,
#    'humidity': 95,
#    'sea_level': 1028,
#    'grnd_level': 985},
#   'wind': {'speed': 1.82, 'deg': 162},
#   'clouds': {'all': 0},
#   'dt': 1579750438,
#   'sys': {'country': 'RU', 'sunrise': 1579744204, 'sunset': 1579771162},
#   'timezone': 25200,
#   'id': 1503037,
#   'name': 'Kodinsk',
#   'cod': 200},
#  {'coord': {'lon': 128.18, 'lat': -3.7},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 34,
#    'feels_like': 37.1,
#    'temp_min': 34,
#    'temp_max': 34,
#    'pressure': 1010,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 250},
#   'clouds': {'all': 40},
#   'dt': 1579750438,
#   'sys': {'type': 1,
#    'id': 9361,
#    'country': 'ID',
#    'sunrise': 1579728592,
#    'sunset': 1579772851},
#   'timezone': 32400,
#   'id': 1651531,
#   'name': 'Ambon',
#   'cod': 200},
#  {'coord': {'lon': 114.6, 'lat': -28.77},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 27,
#    'feels_like': 22.07,
#    'temp_min': 27,
#    'temp_max': 27,
#    'pressure': 1015,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 8.7, 'deg': 180},
#   'clouds': {'all': 0},
#   'dt': 1579750328,
#   'sys': {'type': 1,
#    'id': 9522,
#    'country': 'AU',
#    'sunrise': 1579729422,
#    'sunset': 1579778540},
#   'timezone': 28800,
#   'id': 2070998,
#   'name': 'Geraldton',
#   'cod': 200},
#  {'coord': {'lon': -114.06, 'lat': 27.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 15.74,
#    'feels_like': 13.03,
#    'temp_min': 15.74,
#    'temp_max': 15.74,
#    'pressure': 1019,
#    'humidity': 84,
#    'sea_level': 1019,
#    'grnd_level': 1016},
#   'wind': {'speed': 5.23, 'deg': 327},
#   'clouds': {'all': 0},
#   'dt': 1579750439,
#   'sys': {'country': 'MX', 'sunrise': 1579703245, 'sunset': 1579741662},
#   'timezone': -25200,
#   'id': 4021858,
#   'name': 'Guerrero Negro',
#   'cod': 200},
#  {'coord': {'lon': 2.25, 'lat': 48.17},
#   'weather': [{'id': 701,
#     'main': 'Mist',
#     'description': 'mist',
#     'icon': '50n'}],
#   'base': 'stations',
#   'main': {'temp': -0.96,
#    'feels_like': -6.45,
#    'temp_min': -2.22,
#    'temp_max': 0,
#    'pressure': 1029,
#    'humidity': 92},
#   'visibility': 5000,
#   'wind': {'speed': 4.6, 'deg': 40},
#   'clouds': {'all': 0},
#   'dt': 1579750439,
#   'sys': {'type': 1,
#    'id': 6534,
#    'country': 'FR',
#    'sunrise': 1579764623,
#    'sunset': 1579797278},
#   'timezone': 3600,
#   'id': 2987002,
#   'name': 'Arrondissement de Pithiviers',
#   'cod': 200},
#  {'coord': {'lon': 96.37, 'lat': 61.67},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': -26.62,
#    'feels_like': -31.12,
#    'temp_min': -26.62,
#    'temp_max': -26.62,
#    'pressure': 1022,
#    'humidity': 98,
#    'sea_level': 1022,
#    'grnd_level': 976},
#   'wind': {'speed': 1.04, 'deg': 168},
#   'clouds': {'all': 97},
#   'dt': 1579750324,
#   'sys': {'country': 'RU', 'sunrise': 1579746114, 'sunset': 1579770600},
#   'timezone': 25200,
#   'id': 1510689,
#   'name': 'Baykit',
#   'cod': 200},
#  {'coord': {'lon': 172.79, 'lat': 3.07},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': 29.33,
#    'feels_like': 32.49,
#    'temp_min': 29.33,
#    'temp_max': 29.33,
#    'pressure': 1007,
#    'humidity': 63,
#    'sea_level': 1007,
#    'grnd_level': 1007},
#   'wind': {'speed': 1.86, 'deg': 263},
#   'clouds': {'all': 45},
#   'dt': 1579750350,
#   'sys': {'country': 'KI', 'sunrise': 1579718465, 'sunset': 1579761561},
#   'timezone': 43200,
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': 50.85, 'lat': 58.84},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -8.54,
#    'feels_like': -13.59,
#    'temp_min': -8.54,
#    'temp_max': -8.54,
#    'pressure': 986,
#    'humidity': 94,
#    'sea_level': 986,
#    'grnd_level': 964},
#   'wind': {'speed': 2.92, 'deg': 312},
#   'clouds': {'all': 100},
#   'dt': 1579750440,
#   'sys': {'country': 'RU', 'sunrise': 1579755844, 'sunset': 1579782724},
#   'timezone': 10800,
#   'id': 578152,
#   'name': 'Belaya Kholunitsa',
#   'cod': 200},
#  {'coord': {'lon': -134.97, 'lat': -23.12},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'model',
#   'main': {'temp': 26.45,
#    'feels_like': 27.07,
#    'temp_min': 26.45,
#    'temp_max': 26.45,
#    'pressure': 1017,
#    'humidity': 75,
#    'sea_level': 1017,
#    'grnd_level': 1017},
#   'wind': {'speed': 5.57, 'deg': 89},
#   'clouds': {'all': 12},
#   'dt': 1579750320,
#   'sys': {'country': 'PF', 'sunrise': 1579703528, 'sunset': 1579751418},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 15.16, 'lat': -26.65},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 17,
#    'feels_like': 17.88,
#    'temp_min': 17,
#    'temp_max': 17,
#    'pressure': 1010,
#    'humidity': 82},
#   'wind': {'speed': 0.5, 'deg': 110},
#   'clouds': {'all': 0},
#   'dt': 1579750440,
#   'sys': {'type': 1,
#    'id': 2260,
#    'country': 'NA',
#    'sunrise': 1579753543,
#    'sunset': 1579802160},
#   'timezone': 7200,
#   'id': 3355672,
#   'name': 'Luderitz',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 168.86, 'lat': -46.19},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 17.78,
#    'feels_like': 14.61,
#    'temp_min': 17.78,
#    'temp_max': 17.78,
#    'pressure': 1016,
#    'humidity': 73},
#   'wind': {'speed': 5.81, 'deg': 218, 'gust': 9.39},
#   'clouds': {'all': 43},
#   'dt': 1579750321,
#   'sys': {'type': 3,
#    'id': 2008959,
#    'country': 'NZ',
#    'sunrise': 1579713773,
#    'sunset': 1579768140},
#   'timezone': 46800,
#   'id': 6201424,
#   'name': 'Mataura',
#   'cod': 200},
#  {'coord': {'lon': -73.65, 'lat': -37.62},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 11.51,
#    'feels_like': 11.06,
#    'temp_min': 11.51,
#    'temp_max': 11.51,
#    'pressure': 1013,
#    'humidity': 97,
#    'sea_level': 1013,
#    'grnd_level': 996},
#   'wind': {'speed': 1.13, 'deg': 178},
#   'clouds': {'all': 0},
#   'dt': 1579750319,
#   'sys': {'country': 'CL', 'sunrise': 1579773486, 'sunset': 1579824853},
#   'timezone': -10800,
#   'id': 3883457,
#   'name': 'Lebu',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -8.33, 'lat': 40.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.33,
#    'feels_like': 6.99,
#    'temp_min': 6.67,
#    'temp_max': 10,
#    'pressure': 1014,
#    'humidity': 93},
#   'visibility': 10000,
#   'wind': {'speed': 1},
#   'clouds': {'all': 75},
#   'dt': 1579750385,
#   'sys': {'type': 1,
#    'id': 6896,
#    'country': 'PT',
#    'sunrise': 1579765789,
#    'sunset': 1579801191},
#   'timezone': 0,
#   'id': 2738381,
#   'name': 'Lata',
#   'cod': 200},
#  {'coord': {'lon': 12.2, 'lat': -5.55},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 28.06,
#    'feels_like': 32.99,
#    'temp_min': 28.06,
#    'temp_max': 28.06,
#    'pressure': 1009,
#    'humidity': 78,
#    'sea_level': 1009,
#    'grnd_level': 1009},
#   'wind': {'speed': 1.15, 'deg': 235},
#   'clouds': {'all': 100},
#   'dt': 1579750441,
#   'sys': {'country': 'AO', 'sunrise': 1579756274, 'sunset': 1579800850},
#   'timezone': 3600,
#   'id': 2243271,
#   'name': 'Cabinda',
#   'cod': 200},
#  {'coord': {'lon': -69.45, 'lat': -16.22},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 8.93,
#    'feels_like': 4.41,
#    'temp_min': 8.93,
#    'temp_max': 8.93,
#    'pressure': 1019,
#    'humidity': 83,
#    'sea_level': 1019,
#    'grnd_level': 645},
#   'wind': {'speed': 5.21, 'deg': 43},
#   'rain': {'3h': 1.06},
#   'clouds': {'all': 100},
#   'dt': 1579750441,
#   'sys': {'country': 'PE', 'sunrise': 1579688484, 'sunset': 1579735006},
#   'timezone': -18000,
#   'id': 3937516,
#   'name': 'Juli',
#   'cod': 200},
#  {'coord': {'lon': 118.33, 'lat': 63.28},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': -37.56,
#    'feels_like': -43.11,
#    'temp_min': -37.56,
#    'temp_max': -37.56,
#    'pressure': 1024,
#    'humidity': 95,
#    'sea_level': 1024,
#    'grnd_level': 1004},
#   'wind': {'speed': 2.32, 'deg': 230},
#   'clouds': {'all': 40},
#   'dt': 1579750441,
#   'sys': {'country': 'RU', 'sunrise': 1579741672, 'sunset': 1579764499},
#   'timezone': 32400,
#   'id': 2018735,
#   'name': 'Nyurba',
#   'cod': 200},
#  {'coord': {'lon': -72.22, 'lat': 7.77},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 25,
#    'feels_like': 28.7,
#    'temp_min': 25,
#    'temp_max': 25,
#    'pressure': 1015,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 220},
#   'clouds': {'all': 40},
#   'dt': 1579750441,
#   'sys': {'type': 1,
#    'id': 8587,
#    'country': 'VE',
#    'sunrise': 1579691270,
#    'sunset': 1579733550},
#   'timezone': -14400,
#   'id': 3628473,
#   'name': 'San Cristobal',
#   'cod': 200},
#  {'coord': {'lon': 53.15, 'lat': 67.68},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': -9.77,
#    'feels_like': -17.03,
#    'temp_min': -9.77,
#    'temp_max': -9.77,
#    'pressure': 977,
#    'humidity': 94,
#    'sea_level': 977,
#    'grnd_level': 973},
#   'wind': {'speed': 5.95, 'deg': 28},
#   'snow': {'3h': 0.44},
#   'clouds': {'all': 100},
#   'dt': 1579750442,
#   'sys': {'country': 'RU', 'sunrise': 1579760521, 'sunset': 1579776943},
#   'timezone': 10800,
#   'id': 866062,
#   'name': 'Iskateley',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -175.2, 'lat': -21.2},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 28,
#    'feels_like': 29.36,
#    'temp_min': 28,
#    'temp_max': 28,
#    'pressure': 1008,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 130},
#   'clouds': {'all': 40},
#   'dt': 1579750329,
#   'sys': {'type': 1,
#    'id': 7285,
#    'country': 'TO',
#    'sunrise': 1579799827,
#    'sunset': 1579847265},
#   'timezone': 46800,
#   'id': 4032243,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': 4.27, 'lat': 39.89},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 14,
#    'feels_like': 12.76,
#    'temp_min': 14,
#    'temp_max': 14,
#    'pressure': 1019,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 150},
#   'clouds': {'all': 76},
#   'dt': 1579750442,
#   'sys': {'type': 1,
#    'id': 6422,
#    'country': 'ES',
#    'sunrise': 1579762726,
#    'sunset': 1579798204},
#   'timezone': 3600,
#   'id': 2514301,
#   'name': 'Mahon',
#   'cod': 200},
#  {'coord': {'lon': -70.92, 'lat': -53.15},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 8.95,
#    'feels_like': 3.83,
#    'temp_min': 8.89,
#    'temp_max': 9,
#    'pressure': 1004,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 20},
#   'clouds': {'all': 75},
#   'dt': 1579750340,
#   'sys': {'type': 1,
#    'id': 8487,
#    'country': 'CL',
#    'sunrise': 1579769735,
#    'sunset': 1579827294},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': -61.49, 'lat': -31.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 23.76,
#    'feels_like': 25.15,
#    'temp_min': 23.33,
#    'temp_max': 24.44,
#    'pressure': 1013,
#    'humidity': 59},
#   'wind': {'speed': 0.45, 'deg': 183, 'gust': 2.68},
#   'clouds': {'all': 0},
#   'dt': 1579750442,
#   'sys': {'type': 3,
#    'id': 2007137,
#    'country': 'AR',
#    'sunrise': 1579771414,
#    'sunset': 1579821087},
#   'timezone': -10800,
#   'id': 3839479,
#   'name': 'Rafaela',
#   'cod': 200},
#  {'coord': {'lon': 17.94, 'lat': -33.01},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 19,
#    'feels_like': 18.86,
#    'temp_min': 19,
#    'temp_max': 19,
#    'pressure': 1009,
#    'humidity': 63},
#   'wind': {'speed': 1, 'deg': 70},
#   'clouds': {'all': 0},
#   'dt': 1579750356,
#   'sys': {'type': 1,
#    'id': 1943,
#    'country': 'ZA',
#    'sunrise': 1579752118,
#    'sunset': 1579802250},
#   'timezone': 7200,
#   'id': 3361934,
#   'name': 'Saldanha',
#   'cod': 200},
#  {'coord': {'lon': 115.33, 'lat': -33.65},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 25.35,
#    'feels_like': 22.08,
#    'temp_min': 23.89,
#    'temp_max': 26.67,
#    'pressure': 1011,
#    'humidity': 31},
#   'wind': {'speed': 3.67, 'deg': 193},
#   'clouds': {'all': 100},
#   'dt': 1579750318,
#   'sys': {'type': 3,
#    'id': 2011706,
#    'country': 'AU',
#    'sunrise': 1579728645,
#    'sunset': 1579778967},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -72.78, 'lat': 47.43},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -2.99,
#    'feels_like': -7.96,
#    'temp_min': -2.99,
#    'temp_max': -2.99,
#    'pressure': 1020,
#    'humidity': 88,
#    'sea_level': 1020,
#    'grnd_level': 980},
#   'wind': {'speed': 3.42, 'deg': 218},
#   'clouds': {'all': 100},
#   'dt': 1579750185,
#   'sys': {'country': 'CA', 'sunrise': 1579696128, 'sunset': 1579728960},
#   'timezone': -18000,
#   'id': 6050416,
#   'name': 'La Tuque',
#   'cod': 200},
#  {'coord': {'lon': -114.35, 'lat': 62.46},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': -14.2,
#    'feels_like': -18.33,
#    'temp_min': -14.44,
#    'temp_max': -14,
#    'pressure': 1003,
#    'humidity': 84},
#   'visibility': 8047,
#   'wind': {'speed': 0.99, 'deg': 170},
#   'clouds': {'all': 90},
#   'dt': 1579750220,
#   'sys': {'type': 1,
#    'id': 1007,
#    'country': 'CA',
#    'sunrise': 1579710731,
#    'sunset': 1579734316},
#   'timezone': -25200,
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': -79.24, 'lat': 42.1},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': -4.74,
#    'feels_like': -10.44,
#    'temp_min': -8.89,
#    'temp_max': 0,
#    'pressure': 1026,
#    'humidity': 58},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 190},
#   'clouds': {'all': 1},
#   'dt': 1579750329,
#   'sys': {'type': 1,
#    'id': 4588,
#    'country': 'US',
#    'sunrise': 1579696737,
#    'sunset': 1579731453},
#   'timezone': -18000,
#   'id': 5122534,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 147.33, 'lat': -42.88},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09d'}],
#   'base': 'stations',
#   'main': {'temp': 16.98,
#    'feels_like': 14.7,
#    'temp_min': 13.89,
#    'temp_max': 19.44,
#    'pressure': 989,
#    'humidity': 72},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 300},
#   'rain': {'1h': 0.38},
#   'clouds': {'all': 75},
#   'dt': 1579750092,
#   'sys': {'type': 1,
#    'id': 9545,
#    'country': 'AU',
#    'sunrise': 1579719566,
#    'sunset': 1579772682},
#   'timezone': 39600,
#   'id': 2163355,
#   'name': 'Hobart',
#   'cod': 200},
#  {'coord': {'lon': 27.67, 'lat': 64.17},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': -6,
#    'feels_like': -10.38,
#    'temp_min': -6,
#    'temp_max': -6,
#    'pressure': 1010,
#    'humidity': 85},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 290},
#   'clouds': {'all': 8},
#   'dt': 1579750444,
#   'sys': {'type': 1,
#    'id': 1344,
#    'country': 'FI',
#    'sunrise': 1579763906,
#    'sunset': 1579785791},
#   'timezone': 7200,
#   'id': 654901,
#   'name': 'Kajaani',
#   'cod': 200},
#  {'coord': {'lon': -151.75, 'lat': -16.48},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': 28.11,
#    'feels_like': 30.33,
#    'temp_min': 28.11,
#    'temp_max': 28.11,
#    'pressure': 1011,
#    'humidity': 75,
#    'sea_level': 1011,
#    'grnd_level': 1010},
#   'wind': {'speed': 4.52, 'deg': 46},
#   'clouds': {'all': 33},
#   'dt': 1579750283,
#   'sys': {'country': 'PF', 'sunrise': 1579708219, 'sunset': 1579754782},
#   'timezone': -36000,
#   'id': 4034551,
#   'name': 'Faanui',
#   'cod': 200},
#  {'coord': {'lon': 156.12, 'lat': 50.68},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'model',
#   'main': {'temp': -7.57,
#    'feels_like': -14.82,
#    'temp_min': -7.57,
#    'temp_max': -7.57,
#    'pressure': 1009,
#    'humidity': 81,
#    'sea_level': 1009,
#    'grnd_level': 968},
#   'wind': {'speed': 5.96, 'deg': 301},
#   'snow': {'3h': 0.38},
#   'clouds': {'all': 97},
#   'dt': 1579750215,
#   'sys': {'country': 'RU', 'sunrise': 1579728255, 'sunset': 1579759774},
#   'timezone': 39600,
#   'id': 2121385,
#   'name': "Severo-Kuril'sk",
#   'cod': 200},
#  {'coord': {'lon': -46.02, 'lat': -1.2},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 27.57,
#    'feels_like': 28.6,
#    'temp_min': 27.57,
#    'temp_max': 27.57,
#    'pressure': 1011,
#    'humidity': 81,
#    'sea_level': 1011,
#    'grnd_level': 1011},
#   'wind': {'speed': 6.85, 'deg': 21},
#   'rain': {'3h': 0.69},
#   'clouds': {'all': 82},
#   'dt': 1579750444,
#   'sys': {'country': 'BR', 'sunrise': 1579770624, 'sunset': 1579814451},
#   'timezone': -10800,
#   'id': 3402648,
#   'name': 'Carutapera',
#   'cod': 200},
#  {'coord': {'lon': -139.03, 'lat': -9.8},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 27.33,
#    'feels_like': 28.66,
#    'temp_min': 27.33,
#    'temp_max': 27.33,
#    'pressure': 1012,
#    'humidity': 70,
#    'sea_level': 1012,
#    'grnd_level': 1011},
#   'wind': {'speed': 4.34, 'deg': 78},
#   'clouds': {'all': 74},
#   'dt': 1579750325,
#   'sys': {'country': 'PF', 'sunrise': 1579705781, 'sunset': 1579751114},
#   'timezone': -34200,
#   'id': 4020109,
#   'name': 'Atuona',
#   'cod': 200},
#  {'coord': {'lon': 31.18, 'lat': -10.21},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 16.79,
#    'feels_like': 18.61,
#    'temp_min': 16.79,
#    'temp_max': 16.79,
#    'pressure': 1013,
#    'humidity': 99,
#    'sea_level': 1013,
#    'grnd_level': 862},
#   'wind': {'speed': 0.59, 'deg': 204},
#   'rain': {'3h': 4.81},
#   'clouds': {'all': 100},
#   'dt': 1579750445,
#   'sys': {'country': 'ZM', 'sunrise': 1579751308, 'sunset': 1579796703},
#   'timezone': 7200,
#   'id': 912764,
#   'name': 'Kasama',
#   'cod': 200},
#  {'coord': {'lon': 142.37, 'lat': 42.33},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 0.29,
#    'feels_like': -4.52,
#    'temp_min': 0.29,
#    'temp_max': 0.29,
#    'pressure': 1020,
#    'humidity': 54,
#    'sea_level': 1020,
#    'grnd_level': 976},
#   'wind': {'speed': 2.74, 'deg': 324},
#   'clouds': {'all': 3},
#   'dt': 1579750445,
#   'sys': {'country': 'JP', 'sunrise': 1579729971, 'sunset': 1579764659},
#   'timezone': 32400,
#   'id': 2128025,
#   'name': 'Shizunai',
#   'cod': 200},
#  {'coord': {'lon': -77.06, 'lat': 26.54},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 21.31,
#    'feels_like': 14.59,
#    'temp_min': 21.31,
#    'temp_max': 21.31,
#    'pressure': 1015,
#    'humidity': 69,
#    'sea_level': 1015,
#    'grnd_level': 1015},
#   'wind': {'speed': 12.11, 'deg': 33},
#   'rain': {'3h': 0.38},
#   'clouds': {'all': 33},
#   'dt': 1579750445,
#   'sys': {'country': 'BS', 'sunrise': 1579694211, 'sunset': 1579732933},
#   'timezone': -18000,
#   'id': 3571913,
#   'name': 'Marsh Harbour',
#   'cod': 200},
#  {'coord': {'lon': 178.42, 'lat': 69.38},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -28.98,
#    'feels_like': -34.33,
#    'temp_min': -28.98,
#    'temp_max': -28.98,
#    'pressure': 1018,
#    'humidity': 91,
#    'sea_level': 1018,
#    'grnd_level': 1017},
#   'wind': {'speed': 2.16, 'deg': 274},
#   'clouds': {'all': 51},
#   'dt': 1579750235,
#   'sys': {'country': 'RU', 'sunrise': 1579732682, 'sunset': 1579744641},
#   'timezone': 43200,
#   'id': 2123814,
#   'name': 'Leningradskiy',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 16.99,
#    'feels_like': 16.37,
#    'temp_min': 16,
#    'temp_max': 17.78,
#    'pressure': 1016,
#    'humidity': 87},
#   'wind': {'speed': 3.1, 'deg': 140},
#   'rain': {'3h': 0.13},
#   'clouds': {'all': 36},
#   'dt': 1579750318,
#   'sys': {'type': 1,
#    'id': 1966,
#    'country': 'ZA',
#    'sunrise': 1579751414,
#    'sunset': 1579801945},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': -133.04, 'lat': 69.45},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': -26,
#    'feels_like': -32.67,
#    'temp_min': -26,
#    'temp_max': -26,
#    'pressure': 1007,
#    'humidity': 83},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 250},
#   'clouds': {'all': 90},
#   'dt': 1579750341,
#   'sys': {'type': 1,
#    'id': 942,
#    'country': 'CA',
#    'sunrise': 1579721195,
#    'sunset': 1579732824},
#   'timezone': -25200,
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': 27.91, 'lat': -33.02},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 18,
#    'feels_like': 18.15,
#    'temp_min': 18,
#    'temp_max': 18,
#    'pressure': 1016,
#    'humidity': 93},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 260},
#   'clouds': {'all': 40},
#   'dt': 1579750240,
#   'sys': {'type': 1,
#    'id': 1912,
#    'country': 'ZA',
#    'sunrise': 1579749722,
#    'sunset': 1579799859},
#   'timezone': 7200,
#   'id': 1006984,
#   'name': 'East London',
#   'cod': 200},
#  {'coord': {'lon': -50.01, 'lat': -24.79},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 14.04,
#    'feels_like': 12.89,
#    'temp_min': 14.04,
#    'temp_max': 14.04,
#    'pressure': 1012,
#    'humidity': 99,
#    'sea_level': 1012,
#    'grnd_level': 902},
#   'wind': {'speed': 3.4, 'deg': 84},
#   'rain': {'3h': 1.19},
#   'clouds': {'all': 100},
#   'dt': 1579750320,
#   'sys': {'country': 'BR', 'sunrise': 1579769395, 'sunset': 1579817595},
#   'timezone': -10800,
#   'id': 3466704,
#   'name': 'Castro',
#   'cod': 200},
#  {'coord': {'lon': 124.19, 'lat': 6.21},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 27.71,
#    'feels_like': 30.71,
#    'temp_min': 27.71,
#    'temp_max': 27.71,
#    'pressure': 1013,
#    'humidity': 70,
#    'sea_level': 1013,
#    'grnd_level': 1012},
#   'wind': {'speed': 2.23, 'deg': 239},
#   'clouds': {'all': 66},
#   'dt': 1579750446,
#   'sys': {'country': 'PH', 'sunrise': 1579730401, 'sunset': 1579772958},
#   'timezone': 28800,
#   'id': 1696105,
#   'name': 'Palimbang',
#   'cod': 200},
#  {'coord': {'lon': 27.25, 'lat': 31.35},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 10,
#    'feels_like': 7.46,
#    'temp_min': 10,
#    'temp_max': 10,
#    'pressure': 1025,
#    'humidity': 81},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 270},
#   'clouds': {'all': 40},
#   'dt': 1579750446,
#   'sys': {'type': 1,
#    'id': 2517,
#    'country': 'EG',
#    'sunrise': 1579756100,
#    'sunset': 1579793798},
#   'timezone': 7200,
#   'id': 352733,
#   'name': 'Mersa Matruh',
#   'cod': 200},
#  {'coord': {'lon': -25.43, 'lat': 37.72},
#   'weather': [{'id': 520,
#     'main': 'Rain',
#     'description': 'light intensity shower rain',
#     'icon': '09n'}],
#   'base': 'stations',
#   'main': {'temp': 12,
#    'feels_like': 9.5,
#    'temp_min': 12,
#    'temp_max': 12,
#    'pressure': 1028,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 60},
#   'clouds': {'all': 75},
#   'dt': 1579750396,
#   'sys': {'type': 1,
#    'id': 6899,
#    'country': 'PT',
#    'sunrise': 1579769544,
#    'sunset': 1579805646},
#   'timezone': -3600,
#   'id': 3372472,
#   'name': 'Vila Franca do Campo',
#   'cod': 200},
#  {'coord': {'lon': 179.32, 'lat': 63.05},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'model',
#   'main': {'temp': -24.5,
#    'feels_like': -30.39,
#    'temp_min': -24.5,
#    'temp_max': -24.5,
#    'pressure': 1018,
#    'humidity': 94,
#    'sea_level': 1018,
#    'grnd_level': 1017},
#   'wind': {'speed': 3.07, 'deg': 339},
#   'clouds': {'all': 32},
#   'dt': 1579750363,
#   'sys': {'country': 'RU', 'sunrise': 1579726934, 'sunset': 1579749957},
#   'timezone': 43200,
#   'id': 2126710,
#   'name': 'Beringovskiy',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -85.2, 'lat': 32.35},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 7.33,
#    'feels_like': 3.33,
#    'temp_min': 6.67,
#    'temp_max': 8,
#    'pressure': 1025,
#    'humidity': 31},
#   'visibility': 16093,
#   'wind': {'speed': 1.5, 'deg': 40},
#   'clouds': {'all': 75},
#   'dt': 1579750323,
#   'sys': {'type': 1,
#    'id': 4765,
#    'country': 'US',
#    'sunrise': 1579696822,
#    'sunset': 1579734229},
#   'timezone': -21600,
#   'id': 4047434,
#   'name': 'Russell',
#   'cod': 200},
#  {'coord': {'lon': 35.32, 'lat': -15.39},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 16.86,
#    'feels_like': 18.04,
#    'temp_min': 16.86,
#    'temp_max': 16.86,
#    'pressure': 1011,
#    'humidity': 98,
#    'sea_level': 1011,
#    'grnd_level': 932},
#   'wind': {'speed': 1.46, 'deg': 225},
#   'clouds': {'all': 100},
#   'dt': 1579750447,
#   'sys': {'country': 'MW', 'sunrise': 1579749842, 'sunset': 1579796182},
#   'timezone': 7200,
#   'id': 923295,
#   'name': 'Zomba',
#   'cod': 200},
#  {'coord': {'lon': -99.84, 'lat': 50.25},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': -6,
#    'feels_like': -12.48,
#    'temp_min': -6,
#    'temp_max': -6,
#    'pressure': 1016,
#    'humidity': 85},
#   'visibility': 24140,
#   'wind': {'speed': 5.1, 'deg': 50, 'gust': 7.7},
#   'clouds': {'all': 90},
#   'dt': 1579750447,
#   'sys': {'type': 1,
#    'id': 750,
#    'country': 'CA',
#    'sunrise': 1579703207,
#    'sunset': 1579734873},
#   'timezone': -21600,
#   'id': 6074882,
#   'name': 'Minnedosa',
#   'cod': 200},
#  {'coord': {'lon': 114.97, 'lat': -8.19},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 31,
#    'feels_like': 35.87,
#    'temp_min': 31,
#    'temp_max': 31,
#    'pressure': 1011,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 240},
#   'clouds': {'all': 20},
#   'dt': 1579750447,
#   'sys': {'type': 1,
#    'id': 9333,
#    'country': 'ID',
#    'sunrise': 1579731372,
#    'sunset': 1579776413},
#   'timezone': 28800,
#   'id': 1650232,
#   'name': 'Banjar',
#   'cod': 200},
#  {'coord': {'lon': -152.41, 'lat': 57.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': -4,
#    'feels_like': -9.73,
#    'temp_min': -4,
#    'temp_max': -4,
#    'pressure': 1006,
#    'humidity': 53},
#   'visibility': 16093,
#   'wind': {'speed': 3.6, 'deg': 280, 'gust': 8.7},
#   'clouds': {'all': 1},
#   'dt': 1579750358,
#   'sys': {'type': 1,
#    'id': 7668,
#    'country': 'US',
#    'sunrise': 1579717895,
#    'sunset': 1579745423},
#   'timezone': -32400,
#   'id': 5866583,
#   'name': 'Kodiak',
#   'cod': 200},
#  {'coord': {'lon': -54.84, 'lat': -18.92},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'model',
#   'main': {'temp': 24.02,
#    'feels_like': 28.05,
#    'temp_min': 24.02,
#    'temp_max': 24.02,
#    'pressure': 1005,
#    'humidity': 89,
#    'sea_level': 1005,
#    'grnd_level': 958},
#   'wind': {'speed': 1.02, 'deg': 308},
#   'rain': {'3h': 4.94},
#   'clouds': {'all': 100},
#   'dt': 1579750448,
#   'sys': {'country': 'BR', 'sunrise': 1579684714, 'sunset': 1579731761},
#   'timezone': -14400,
#   'id': 3451051,
#   'name': 'Rio Verde de Mato Grosso',
#   'cod': 200},
#  {'coord': {'lon': 30.79, 'lat': 59.7},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': -3.52,
#    'feels_like': -13.7,
#    'temp_min': -4.44,
#    'temp_max': -3,
#    'pressure': 1012,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 10, 'deg': 320, 'gust': 16},
#   'clouds': {'all': 20},
#   'dt': 1579750322,
#   'sys': {'type': 1,
#    'id': 8926,
#    'country': 'RU',
#    'sunrise': 1579760982,
#    'sunset': 1579787217},
#   'timezone': 10800,
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'coord': {'lon': 19.7, 'lat': 13.3},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 12.73,
#    'feels_like': 6.72,
#    'temp_min': 12.73,
#    'temp_max': 12.73,
#    'pressure': 1016,
#    'humidity': 24,
#    'sea_level': 1016,
#    'grnd_level': 971},
#   'wind': {'speed': 4.53, 'deg': 56},
#   'clouds': {'all': 0},
#   'dt': 1579750448,
#   'sys': {'country': 'TD', 'sunrise': 1579756101, 'sunset': 1579797422},
#   'timezone': 3600,
#   'id': 2426370,
#   'name': 'Oum Hadjer',
#   'cod': 200},
#  {'coord': {'lon': 161.3, 'lat': 68.75},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -36.1,
#    'feels_like': -41.57,
#    'temp_min': -36.1,
#    'temp_max': -36.1,
#    'pressure': 1022,
#    'humidity': 98,
#    'sea_level': 1022,
#    'grnd_level': 1020},
#   'wind': {'speed': 2.23, 'deg': 157},
#   'clouds': {'all': 100},
#   'dt': 1579750348,
#   'sys': {'country': 'RU', 'sunrise': 1579735873, 'sunset': 1579749669},
#   'timezone': 39600,
#   'id': 2126199,
#   'name': 'Cherskiy',
#   'cod': 200},
#  {'coord': {'lon': -13.05, 'lat': 20.52},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 15.91,
#    'feels_like': 12.23,
#    'temp_min': 15.91,
#    'temp_max': 15.91,
#    'pressure': 1016,
#    'humidity': 30,
#    'sea_level': 1016,
#    'grnd_level': 972},
#   'wind': {'speed': 2.1, 'deg': 66},
#   'clouds': {'all': 100},
#   'dt': 1579750448,
#   'sys': {'country': 'MR', 'sunrise': 1579764629, 'sunset': 1579804617},
#   'timezone': 0,
#   'id': 2381334,
#   'name': 'Atar',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 145.92, 'lat': -41.07},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 15.56,
#    'feels_like': 14.14,
#    'temp_min': 15.56,
#    'temp_max': 15.56,
#    'pressure': 977,
#    'humidity': 82},
#   'wind': {'speed': 3.13, 'deg': 330, 'gust': 8.49},
#   'rain': {'3h': 3.88},
#   'clouds': {'all': 98},
#   'dt': 1579750449,
#   'sys': {'type': 3,
#    'id': 2009480,
#    'country': 'AU',
#    'sunrise': 1579720213,
#    'sunset': 1579772713},
#   'timezone': 39600,
#   'id': 2173125,
#   'name': 'Burnie',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -70.17, 'lat': 1.2},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 25.32,
#    'feels_like': 28.98,
#    'temp_min': 25.32,
#    'temp_max': 25.32,
#    'pressure': 1009,
#    'humidity': 78,
#    'sea_level': 1009,
#    'grnd_level': 987},
#   'wind': {'speed': 0.9, 'deg': 37},
#   'clouds': {'all': 99},
#   'dt': 1579750449,
#   'sys': {'country': 'CO', 'sunrise': 1579690210, 'sunset': 1579733626},
#   'timezone': -18000,
#   'id': 3674676,
#   'name': 'Mitu',
#   'cod': 200},
#  {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 17.78,
#    'feels_like': 17.82,
#    'temp_min': 17.78,
#    'temp_max': 17.78,
#    'pressure': 1016,
#    'humidity': 95},
#   'wind': {'speed': 3.33, 'deg': 140},
#   'rain': {'3h': 0.19},
#   'clouds': {'all': 92},
#   'dt': 1579750284,
#   'sys': {'type': 3,
#    'id': 2011314,
#    'country': 'ZA',
#    'sunrise': 1579749893,
#    'sunset': 1579800178},
#   'timezone': 7200,
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  {'coord': {'lon': -40.29, 'lat': -20.33},
#   'weather': [{'id': 503,
#     'main': 'Rain',
#     'description': 'very heavy rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 22.71,
#    'feels_like': 26.55,
#    'temp_min': 22.22,
#    'temp_max': 23,
#    'pressure': 1010,
#    'humidity': 94},
#   'visibility': 6000,
#   'wind': {'speed': 1, 'deg': 320},
#   'rain': {'1h': 20.83},
#   'clouds': {'all': 90},
#   'dt': 1579750239,
#   'sys': {'type': 1,
#    'id': 8474,
#    'country': 'BR',
#    'sunrise': 1579767520,
#    'sunset': 1579814803},
#   'timezone': -10800,
#   'id': 3445026,
#   'name': 'Vila Velha',
#   'cod': 200},
#  {'coord': {'lon': -92.99, 'lat': 45.28},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 0.33,
#    'feels_like': -3.86,
#    'temp_min': -0.56,
#    'temp_max': 1.11,
#    'pressure': 1014,
#    'humidity': 96},
#   'visibility': 6437,
#   'wind': {'speed': 3.1, 'deg': 160},
#   'rain': {'1h': 0.25},
#   'snow': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1579750445,
#   'sys': {'type': 1,
#    'id': 5179,
#    'country': 'US',
#    'sunrise': 1579700573,
#    'sunset': 1579734219},
#   'timezone': -21600,
#   'id': 5027117,
#   'name': 'Forest Lake',
#   'cod': 200},
#  {'coord': {'lon': -119.74, 'lat': 49.77},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 1.39,
#    'feels_like': -2.36,
#    'temp_min': 1,
#    'temp_max': 2,
#    'pressure': 1018,
#    'humidity': 93},
#   'visibility': 14484,
#   'wind': {'speed': 2.6, 'deg': 130},
#   'clouds': {'all': 90},
#   'dt': 1579750450,
#   'sys': {'type': 1,
#    'id': 852,
#    'country': 'CA',
#    'sunrise': 1579707874,
#    'sunset': 1579739760},
#   'timezone': -28800,
#   'id': 6100086,
#   'name': 'Peachland',
#   'cod': 200},
#  {'coord': {'lon': -122.7, 'lat': 58.81},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': -18,
#    'feels_like': -21.72,
#    'temp_min': -18,
#    'temp_max': -18,
#    'pressure': 1005,
#    'humidity': 91},
#   'visibility': 24140,
#   'wind': {'speed': 0.24, 'deg': 130},
#   'clouds': {'all': 20},
#   'dt': 1579750400,
#   'sys': {'type': 1,
#    'id': 986,
#    'country': 'CA',
#    'sunrise': 1579711140,
#    'sunset': 1579737915},
#   'timezone': -25200,
#   'id': 5955902,
#   'name': 'Fort Nelson',
#   'cod': 200},
#  {'coord': {'lon': 128.02, 'lat': 43.56},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'model',
#   'main': {'temp': -3.21,
#    'feels_like': -9.77,
#    'temp_min': -3.21,
#    'temp_max': -3.21,
#    'pressure': 1023,
#    'humidity': 82,
#    'sea_level': 1023,
#    'grnd_level': 948},
#   'wind': {'speed': 5.52, 'deg': 272},
#   'snow': {'3h': 0.25},
#   'clouds': {'all': 89},
#   'dt': 1579750450,
#   'sys': {'country': 'CN', 'sunrise': 1579733614, 'sunset': 1579767905},
#   'timezone': 28800,
#   'id': 2036734,
#   'name': 'Huangnihe',
#   'cod': 200},
#  {'coord': {'lon': 28.1, 'lat': 8.53},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 14.52,
#    'feels_like': 9.65,
#    'temp_min': 14.52,
#    'temp_max': 14.52,
#    'pressure': 1014,
#    'humidity': 21,
#    'sea_level': 1014,
#    'grnd_level': 966},
#   'wind': {'speed': 2.88, 'deg': 1},
#   'clouds': {'all': 63},
#   'dt': 1579750450,
#   'sys': {'country': 'SS', 'sunrise': 1579753665, 'sunset': 1579795825},
#   'timezone': 10800,
#   'id': 374739,
#   'name': 'Gogrial',
#   'cod': 200},
#  {'coord': {'lon': 48.48, 'lat': 8.41},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
# ...
#   'sys': {'country': 'AF', 'sunrise': 1579746629, 'sunset': 1579782971},
#   'timezone': 16200,
#   'id': 1123004,
#   'name': 'Taloqan',
#   'cod': 200},
#  {'coord': {'lon': -174.35, 'lat': -19.8},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 29,
#    'feels_like': 32.4,
#    'temp_min': 29,
#    'temp_max': 29,
#    'pressure': 1007,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 100},
#   'clouds': {'all': 20},
#   'dt': 1579750538,
#   'sys': {'type': 1,
#    'id': 7286,
#    'country': 'TO',
#    'sunrise': 1579799762,
#    'sunset': 1579846922},
#   'timezone': 46800,
#   'id': 4032369,
#   'name': 'Pangai',
#   'cod': 200},
#  {'coord': {'lon': -52.95, 'lat': 5.38},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'model',
#   'main': {'temp': 25.62,
#    'feels_like': 25.58,
#    'temp_min': 25.62,
#    'temp_max': 25.62,
#    'pressure': 1013,
#    'humidity': 74,
#    'sea_level': 1013,
#    'grnd_level': 1012},
#   'wind': {'speed': 5.78, 'deg': 62},
#   'clouds': {'all': 9},
#   'dt': 1579750274,
#   'sys': {'country': 'GF', 'sunrise': 1579772848, 'sunset': 1579815554},
#   'timezone': -10800,
#   'id': 3380290,
#   'name': 'Sinnamary',
#   'cod': 200},
#  {'coord': {'lon': 30.48, 'lat': -22.95},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': 18.54,
#    'feels_like': 19.95,
#    'temp_min': 18.54,
#    'temp_max': 18.54,
#    'pressure': 1011,
#    'humidity': 80,
#    'sea_level': 1011,
#    'grnd_level': 941},
#   'wind': {'speed': 0.31, 'deg': 357},
#   'clouds': {'all': 0},
#   'dt': 1579750539,
#   'sys': {'country': 'ZA', 'sunrise': 1579750261, 'sunset': 1579798086},
#   'timezone': 7200,
#   'id': 949224,
#   'name': 'Thohoyandou',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 124.28, 'lat': -9.86},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'model',
#   'main': {'temp': 30.43,
#    'feels_like': 33.81,
#    'temp_min': 30.43,
#    'temp_max': 30.43,
#    'pressure': 1010,
#    'humidity': 60,
#    'sea_level': 1010,
#    'grnd_level': 971},
#   'wind': {'speed': 1.72, 'deg': 192},
#   'rain': {'3h': 0.31},
#   'clouds': {'all': 6},
#   'dt': 1579750539,
#   'sys': {'country': 'ID', 'sunrise': 1579728988, 'sunset': 1579774327},
#   'timezone': 28800,
#   'id': 1626703,
#   'name': 'Soe',
#   'cod': 200},
#  {'coord': {'lon': 116.29, 'lat': 37.45},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'model',
#   'main': {'temp': 5.39,
#    'feels_like': 2.36,
#    'temp_min': 5.39,
#    'temp_max': 5.39,
#    'pressure': 1028,
#    'humidity': 67,
#    'sea_level': 1028,
#    'grnd_level': 1026},
#   'wind': {'speed': 1.44, 'deg': 17},
#   'clouds': {'all': 11},
#   'dt': 1579750374,
#   'sys': {'country': 'CN', 'sunrise': 1579735507, 'sunset': 1579771644},
#   'timezone': 28800,
#   'id': 1812955,
#   'name': 'Dezhou',
#   'cod': 200},
#  {'coord': {'lon': 145.57, 'lat': 43.32},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 0,
#    'feels_like': -4.18,
#    'temp_min': 0,
#    'temp_max': 0,
#    'pressure': 1018,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 360},
#   'clouds': {'all': 20},
#   'dt': 1579750539,
#   'sys': {'type': 1,
#    'id': 7976,
#    'country': 'JP',
#    'sunrise': 1579729365,
#    'sunset': 1579763729},
#   'timezone': 32400,
#   'id': 2128975,
#   'name': 'Nemuro',
#   'cod': 200},
#  {'coord': {'lon': 73.83, 'lat': 57.13},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'}],
#   'base': 'model',
#   'main': {'temp': -5.08,
#    'feels_like': -12.61,
#    'temp_min': -5.08,
#    'temp_max': -5.08,
#    'pressure': 995,
#    'humidity': 91,
#    'sea_level': 995,
#    'grnd_level': 986},
#   'wind': {'speed': 6.84, 'deg': 179},
#   'snow': {'3h': 0.69},
#   'clouds': {'all': 100},
#   'dt': 1579750540,
#   'sys': {'country': 'RU', 'sunrise': 1579749739, 'sunset': 1579777797},
#   'timezone': 21600,
#   'id': 1485020,
#   'name': 'Znamenskoye',
#   'cod': 200},
#  {'coord': {'lon': -22.73, 'lat': 65.08},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13n'}],
#   'base': 'model',
#   'main': {'temp': -1.37,
#    'feels_like': -15.37,
#    'temp_min': -1.37,
#    'temp_max': -1.37,
#    'pressure': 991,
#    'humidity': 63,
#    'sea_level': 991,
#    'grnd_level': 971},
#   'wind': {'speed': 15.93, 'deg': 231},
#   'snow': {'3h': 0.75},
#   'clouds': {'all': 100},
#   'dt': 1579750540,
#   'sys': {'country': 'IS', 'sunrise': 1579776558, 'sunset': 1579797335},
#   'timezone': 0,
#   'id': 3412888,
#   'name': 'Stykkisholmur',
#   'cod': 200},
#  {'coord': {'lon': 123.37, 'lat': 66.77},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': -32.68,
#    'feels_like': -38.56,
#    'temp_min': -32.68,
#    'temp_max': -32.68,
#    'pressure': 1022,
#    'humidity': 89,
#    'sea_level': 1022,
#    'grnd_level': 1016},
#   'wind': {'speed': 2.85, 'deg': 341},
#   'clouds': {'all': 100},
#   'dt': 1579750540,
#   'sys': {'country': 'RU', 'sunrise': 1579742862, 'sunset': 1579760890},
#   'timezone': 32400,
#   'id': 2012530,
#   'name': 'Zhigansk',
#   'cod': 200},
#  {'coord': {'lon': 129.55, 'lat': -14.25},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 30.63,
#    'feels_like': 33.65,
#    'temp_min': 30.63,
#    'temp_max': 30.63,
#    'pressure': 1006,
#    'humidity': 77,
#    'sea_level': 1006,
#    'grnd_level': 1005},
#   'wind': {'speed': 5.89, 'deg': 287},
#   'clouds': {'all': 100},
#   'dt': 1579750540,
#   'sys': {'country': 'AU', 'sunrise': 1579727324, 'sunset': 1579773461},
#   'timezone': 34200,
#   'id': 2063039,
#   'name': 'Port Keats',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': -66.97, 'lat': -18.37},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 10,
#    'feels_like': 6.2,
#    'temp_min': 10,
#    'temp_max': 10,
#    'pressure': 1034,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 80},
#   'clouds': {'all': 75},
#   'dt': 1579750541,
#   'sys': {'type': 1,
#    'id': 8625,
#    'country': 'BO',
#    'sunrise': 1579687681,
#    'sunset': 1579734618},
#   'timezone': -14400,
#   'id': 3907685,
#   'name': 'Poopo',
#   'cod': 200},
#  {'coord': {'lon': 38.12, 'lat': -6.75},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 24,
#    'feels_like': 29.66,
#    'temp_min': 24,
#    'temp_max': 24,
#    'pressure': 1010,
#    'humidity': 100},
#   'visibility': 10000,
#   'wind': {'speed': 0.22, 'deg': 354},
#   'clouds': {'all': 75},
#   'dt': 1579750541,
#   'sys': {'type': 1,
#    'id': 2615,
#    'country': 'TZ',
#    'sunrise': 1579749947,
#    'sunset': 1579794733},
#   'timezone': 10800,
#   'id': 151678,
#   'name': 'Ngerengere',
#   'cod': 200},
#  {'coord': {'lon': 55, 'lat': 59.94},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -9.3,
#    'feels_like': -14.17,
#    'temp_min': -9.3,
#    'temp_max': -9.3,
#    'pressure': 982,
#    'humidity': 96,
#    'sea_level': 982,
#    'grnd_level': 962},
#   'wind': {'speed': 2.61, 'deg': 280},
#   'clouds': {'all': 100},
#   'dt': 1579750541,
#   'sys': {'country': 'RU', 'sunrise': 1579755275, 'sunset': 1579781301},
#   'timezone': 18000,
#   'id': 544318,
#   'name': 'Kosa',
#   'cod': 200},
#  {'coord': {'lon': 150.85, 'lat': 65.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'model',
#   'main': {'temp': -35.12,
#    'feels_like': -40,
#    'temp_min': -35.12,
#    'temp_max': -35.12,
#    'pressure': 1022,
#    'humidity': 94,
#    'sea_level': 1022,
#    'grnd_level': 1015},
#   'wind': {'speed': 1.39, 'deg': 162},
#   'clouds': {'all': 4},
#   'dt': 1579750415,
#   'sys': {'country': 'RU', 'sunrise': 1579735463, 'sunset': 1579755096},
#   'timezone': 39600,
#   'id': 2119283,
#   'name': 'Zyryanka',
#   'cod': 200},
#  {'cod': '404', 'message': 'city not found'},
#  {'coord': {'lon': 43.98, 'lat': 26.33},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 3,
#    'feels_like': -0.55,
#    'temp_min': 3,
#    'temp_max': 3,
#    'pressure': 1021,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'clouds': {'all': 0},
#   'dt': 1579750542,
#   'sys': {'type': 1,
#    'id': 7411,
#    'country': 'SA',
#    'sunrise': 1579751529,
#    'sunset': 1579790337},
#   'timezone': 10800,
#   'id': 107304,
#   'name': 'Buraidah',
#   'cod': 200},
#  {'coord': {'lon': -59.95, 'lat': 3.08},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': 26.13,
#    'feels_like': 26.92,
#    'temp_min': 26.13,
#    'temp_max': 26.13,
#    'pressure': 1010,
#    'humidity': 58,
#    'sea_level': 1010,
#    'grnd_level': 998},
#   'wind': {'speed': 2.39, 'deg': 18},
#   'clouds': {'all': 95},
#   'dt': 1579750542,
#   'sys': {'country': 'BR', 'sunrise': 1579687918, 'sunset': 1579731011},
#   'timezone': -14400,
#   'id': 3405215,
#   'name': 'Bonfim',
#   'cod': 200},
#  {'coord': {'lon': 136.63, 'lat': 50.72},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': -18.55,
#    'feels_like': -23.56,
#    'temp_min': -18.55,
#    'temp_max': -18.55,
#    'pressure': 1020,
#    'humidity': 97,
#    'sea_level': 1020,
#    'grnd_level': 960},
#   'wind': {'speed': 2.09, 'deg': 154},
#   'clouds': {'all': 39},
#   'dt': 1579750542,
#   'sys': {'country': 'RU', 'sunrise': 1579732938, 'sunset': 1579764448},
#   'timezone': 36000,
#   'id': 2016307,
#   'name': 'Solnechnyy',
#   'cod': 200},
#  {'coord': {'lon': 50.1, 'lat': 61.07},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -8.59,
#    'feels_like': -14.43,
#    'temp_min': -8.59,
#    'temp_max': -8.59,
#    'pressure': 985,
#    'humidity': 91,
#    'sea_level': 985,
#    'grnd_level': 967},
#   'wind': {'speed': 4, 'deg': 292},
#   'clouds': {'all': 100},
#   'dt': 1579750542,
#   'sys': {'country': 'RU', 'sunrise': 1579756928, 'sunset': 1579782000},
#   'timezone': 10800,
#   'id': 473263,
#   'name': 'Vizinga',
#   'cod': 200},
#  {'coord': {'lon': 76.57, 'lat': 24.03},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'model',
#   'main': {'temp': 13.5,
#    'feels_like': 9.67,
#    'temp_min': 13.5,
#    'temp_max': 13.5,
#    'pressure': 1021,
#    'humidity': 49,
#    'sea_level': 1021,
#    'grnd_level': 973},
#   'wind': {'speed': 3.32, 'deg': 54},
#   'clouds': {'all': 31},
#   'dt': 1579750542,
#   'sys': {'country': 'IN', 'sunrise': 1579743470, 'sunset': 1579782750},
#   'timezone': 19800,
#   'id': 1266731,
#   'name': 'Khilchipur',
#   'cod': 200},
#  {'coord': {'lon': 8.55, 'lat': 36.47},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 9.89,
#    'feels_like': 8.92,
#    'temp_min': 5,
#    'temp_max': 16,
#    'pressure': 1024,
#    'humidity': 93},
#   'wind': {'speed': 1, 'deg': 100},
#   'clouds': {'all': 20},
#   'dt': 1579750542,
#   'sys': {'type': 1,
#    'id': 1216,
#    'country': 'TN',
#    'sunrise': 1579761223,
#    'sunset': 1579797653},
#   'timezone': 3600,
#   'id': 2464157,
#   'name': 'Oued Meliz',
#   'cod': 200},
#  {'coord': {'lon': 19.93, 'lat': 60.1},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 1,
#    'feels_like': -3.09,
#    'temp_min': 1,
#    'temp_max': 1,
#    'pressure': 1021,
#    'humidity': 80},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 290},
#   'clouds': {'all': 17},
#   'dt': 1579750400,
#   'sys': {'type': 1,
#    'id': 1347,
#    'country': 'AX',
#    'sunrise': 1579763745,
#    'sunset': 1579789667},
#   'timezone': 7200,
#   'id': 3041732,
#   'name': 'Mariehamn',
#   'cod': 200},
#  {'coord': {'lon': -149.15, 'lat': -17.73},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 30,
#    'feels_like': 32.2,
#    'temp_min': 30,
#    'temp_max': 30,
#    'pressure': 1012,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 60},
#   'clouds': {'all': 20},
#   'dt': 1579750377,
#   'sys': {'type': 1,
#    'id': 7318,
#    'country': 'PF',
#    'sunrise': 1579707475,
#    'sunset': 1579754278},
#   'timezone': -36000,
#   'id': 4033557,
#   'name': 'Tautira',
#   'cod': 200},
#  {'coord': {'lon': -94.13, 'lat': 36.19},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 2.26,
#    'feels_like': -2.41,
#    'temp_min': 1.11,
#    'temp_max': 3,
#    'pressure': 1015,
#    'humidity': 93},
#   'visibility': 16093,
#   'wind': {'speed': 4.1, 'deg': 170},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1579750507,
#   'sys': {'type': 1,
#    'id': 6287,
#    'country': 'US',
#    'sunrise': 1579699451,
#    'sunset': 1579735888},
#   'timezone': -21600,
#   'id': 4132093,
#   'name': 'Springdale',
#   'cod': 200},
#  {'coord': {'lon': 42.9, 'lat': 62.11},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'model',
#   'main': {'temp': -6.76,
#    'feels_like': -13.26,
#    'temp_min': -6.76,
#    'temp_max': -6.76,
#    'pressure': 991,
#    'humidity': 85,
#    'sea_level': 991,
#    'grnd_level': 982},
#   'wind': {'speed': 5.04, 'deg': 304},
#   'clouds': {'all': 100},
#   'dt': 1579750543,
#   'sys': {'country': 'RU', 'sunrise': 1579759138, 'sunset': 1579783247},
#   'timezone': 10800,
#   'id': 494884,
#   'name': 'Shenkursk',
#   'cod': 200},
#  {'coord': {'lon': 129.21, 'lat': 35.24},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 7,
#    'feels_like': 3.55,
#    'temp_min': 7,
#    'temp_max': 7,
#    'pressure': 1022,
#    'humidity': 93},
#   'visibility': 4800,
#   'wind': {'speed': 3.6, 'deg': 330},
#   'clouds': {'all': 90},
#   'dt': 1579750543,
#   'sys': {'type': 1,
#    'id': 8086,
#    'country': 'KR',
#    'sunrise': 1579732114,
#    'sunset': 1579768834},
#   'timezone': 32400,
#   'id': 1842966,
#   'name': 'Gijang',
#   'cod': 200},
#  {'coord': {'lon': 105.02, 'lat': 33.23},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 3.96,
#    'feels_like': 0.62,
#    'temp_min': 3.96,
#    'temp_max': 3.96,
#    'pressure': 1020,
#    'humidity': 61,
#    'sea_level': 1020,
#    'grnd_level': 840},
#   'wind': {'speed': 1.38, 'deg': 8},
#   'clouds': {'all': 100},
#   'dt': 1579750543,
#   'sys': {'country': 'CN', 'sunrise': 1579737665, 'sunset': 1579774896},
#   'timezone': 28800,
#   'id': 7341918,
#   'name': 'Moba',
#   'cod': 200},
#  {'coord': {'lon': 32.04, 'lat': -28.78},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'model',
#   'main': {'temp': 23.6,
#    'feels_like': 24.66,
#    'temp_min': 23.6,
#    'temp_max': 23.6,
#    'pressure': 1013,
#    'humidity': 77,
#    'sea_level': 1013,
#    'grnd_level': 1012},
#   'wind': {'speed': 3.31, 'deg': 340},
#   'clouds': {'all': 100},
#   'dt': 1579750544,
#   'sys': {'country': 'ZA', 'sunrise': 1579749248, 'sunset': 1579798351},
#   'timezone': 7200,
#   'id': 962367,
#   'name': 'Richards Bay',
#   'cod': 200}]

# %%
#cityid = []
name = []
country = []
lat = []
lng = []
cloud = []
humidity = []
maxtemp = []
wind = []
date = []

#for id in enumerate(range(len(responses))):
 #   cityid.append(id)
for city in cities:
    city_data = requests.get(weather_url + city).json()
    name.append(city_data['name'])
    country.append(city_data['sys']['country'])
    lat.append(city_data['coord']['lat'])
    lng.append(city_data['coord']['lon'])
    cloud.append(city_data['clouds']['all'])
    humidity.append(city_data['main']['humidity'])
    maxtemp.append(city_data['main']['temp_max'])
    wind.append(city_data['wind']['speed'])
    date.append(city_data['dt'])

city_dict = {
    #"City ID":cityid,
    "City Name":name,
    "Country":country,
    "Lat":lat,
    "Lng":lng,
    "Cloudiness":cloud,
    "Humidity":humidity,
    "Max Temp":maxtemp,
    "Wind Speed":wind,
    "Date":date
}
city_dict
#city_pd = pd.DataFrame(city_dict)
#city_pd.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-92bc93f90c22> in <module>
#      14 for city in cities:
#      15     city_data = requests.get(weather_url + city).json()
# ---> 16     name.append(city_data['name'])
#      17     country.append(city_data['sys']['country'])
#      18     lat.append(city_data['coord']['lat'])
#
# KeyError: 'name'

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
